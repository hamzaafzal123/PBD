# %%
import pandas as pd
import numpy as np
d = pd.read_csv("file.csv")#I Change filename because that file name is giving some error and not read file
d.head(10)
# Out:
#        study_id  subtlety  size age  gender       x       y      state  \
# 0  JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0  malignant
# 1  JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0     benign
# 2  JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0  malignant
# 3  JPCLN004.png       5.0  14.0  68  Female   606.0   836.0     benign
# 4  JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0  malignant
# 5  JPCLN006.png       5.0  14.0  64  Female   660.0   524.0     benign
# 6  JPCLN007.png       5.0  18.0  69    Male   459.0   852.0  malignant
# 7  JPCLN008.png       5.0  10.0  44  Female   508.0   938.0     benign
# 8  JPCLN009.png       5.0  28.0  61  Female  1593.0   930.0  malignant
# 9  JPCLN010.png       5.0  25.0  60  Female   647.0   594.0  malignant
#
#              position           diagnosis
# 0        l.upper lobe         lung cancer
# 1    l.upper lobe(S5)  pulmonary hematoma
# 2  l.upper lobe(S1+2)         lung cancer
# ...

# %%
d.tail(10)
# Out:
#          study_id  subtlety  size age  gender   x   y       state position  \
# 237  JPCNN084.png       NaN   NaN  53  Female NaN NaN  non-nodule      NaN
# 238  JPCNN085.png       NaN   NaN  68  Female NaN NaN  non-nodule      NaN
# 239  JPCNN086.png       NaN   NaN  47    Male NaN NaN  non-nodule      NaN
# 240  JPCNN087.png       NaN   NaN  77  Female NaN NaN  non-nodule      NaN
# 241  JPCNN088.png       NaN   NaN  54    Male NaN NaN  non-nodule      NaN
# 242  JPCNN089.png       NaN   NaN  50    Male NaN NaN  non-nodule      NaN
# 243  JPCNN090.png       NaN   NaN  68  Female NaN NaN  non-nodule      NaN
# 244  JPCNN091.png       NaN   NaN  81    Male NaN NaN  non-nodule      NaN
# 245  JPCNN092.png       NaN   NaN  70  Female NaN NaN  non-nodule      NaN
# 246  JPCNN093.png       NaN   NaN  41    Male NaN NaN  non-nodule      NaN
#
#     diagnosis
# 237       NaN
# 238       NaN
# 239       NaN
# 240       NaN
# 241       NaN
# 242       NaN
# 243       NaN
# 244       NaN
# ...

# %%
d['gender'].isnull().sum()
# Out:
# 0

# %%
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.pie(d['gender'].value_counts(),explode=[0,0.6],
               shadow=True,labels=['MALE','FEMALE'],autopct='%1.1f%%',
              startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x2189bf4adf0>,
# ...
#  [Text(-1.098198743276378, -0.06292471903937331, 'MALE'),
#   Text(1.6972162396089479, 0.0972472930608487, 'FEMALE')],
#  [Text(-0.5990174963325697, -0.03432257402147635, '51.8%'),
#   Text(1.1980349926651395, 0.068645148042952, '48.2%')])
