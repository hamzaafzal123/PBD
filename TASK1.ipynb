# %%
import pandas as pd
import numpy as np
d = pd.read_csv("file.csv")#I Change filename because that file name is giving some error and not read file
d.head(15)
# Out:
#         study_id  subtlety  size age  gender       x       y      state  \
# 0   JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0  malignant
# 1   JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0     benign
# 2   JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0  malignant
# 3   JPCLN004.png       5.0  14.0  68  Female   606.0   836.0     benign
# 4   JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0  malignant
# 5   JPCLN006.png       5.0  14.0  64  Female   660.0   524.0     benign
# 6   JPCLN007.png       5.0  18.0  69    Male   459.0   852.0  malignant
# 7   JPCLN008.png       5.0  10.0  44  Female   508.0   938.0     benign
# 8   JPCLN009.png       5.0  28.0  61  Female  1593.0   930.0  malignant
# 9   JPCLN010.png       5.0  25.0  60  Female   647.0   594.0  malignant
# 10  JPCLN011.png       5.0  20.0  68    Male   647.0   401.0     benign
# 11  JPCLN012.png       5.0  37.0  80    Male   268.0  1136.0  malignant
# ...

# %%
d['diagnosis'].values
# Out:
# array(['lung cancer', 'pulmonary hematoma', 'lung cancer',
#        'Inflammatory mass', 'lung cancer', 'tuberculoma', 'lung cancer',
#        'granuloma', 'lung cancer', 'lung cancer', 'tuberculoma',
#        'lung cancer', 'tuberculoma', 'lung cancer', 'lung cancer',
#        'lung cancer(adenocarcinoma)', 'lung cancer(adenocarcinoma)',
#        'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer',
#        'lung cancer', 'lung cancer', 'hamartoma', 'unknown',
#        'lung abscess', 'lung cancer(bronchioloalveolar cell carcinoma)',
#        'lung cancer', 'lung cancer', 'Cryptococcosis', 'lung cancer',
#        'lung cancer', 'lung cancer(bronchioloalveolar cell carcinoma)',
#        'tuberculoma', 'lung cancer(adenocarcinoma)', 'tuberculoma',
#        'lung cancer', 'lung cancer(adenocarcinoma)', 'lung cancer',
#        'lung cancer(adenocarcinoma)', 'lung cancer', 'lung cancer',
#        'tuberculoma', 'lung cancer', 'lung cancer(adenocarcinoma)',
# ...

# %%
d['diagnosis'].value_counts()
# Out:
# lung cancer                                       56
# lung cancer(adenocarcinoma)                       23
# tuberculoma                                       14
# granuloma                                          8
# lung cancer(bronchioloalveolar cell carcinoma)     7
# unknown                                            4
# metastasis of colon cancer                         4
# inflammatory mass                                  4
# pulmonary tuberculosis                             3
# lung abscess                                       2
# Cryptococcosis                                     2
# lung cancer(squamous cell carcinoma)               2
# Inflammatory mass                                  2
# pulmonary hematoma                                 2
# susp. inflammatory mass                            2
# hamartoma                                          2
# sclerosing hemangioma                              2
# lung cancer(large cell carcinoma)                  1
# ...

# %%
d['diagnosis'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 242     True
# 243     True
# 244     True
# 245     True
# 246     True
# Name: diagnosis, Length: 247, dtype: bool

# %%
max_diseases = d['diagnosis'].value_counts().idxmax()
max_diseases
# Out:
# 'lung cancer'

# %%
import numpy as np
d['diagnosis'].replace(np.nan,max_diseases,inplace=True)#REPLACING BEACUSE NULL PLACES IS GIVEING ERROR
d['diagnosis'].values
# Out:
# array(['lung cancer', 'pulmonary hematoma', 'lung cancer',
#        'Inflammatory mass', 'lung cancer', 'tuberculoma', 'lung cancer',
#        'granuloma', 'lung cancer', 'lung cancer', 'tuberculoma',
#        'lung cancer', 'tuberculoma', 'lung cancer', 'lung cancer',
#        'lung cancer(adenocarcinoma)', 'lung cancer(adenocarcinoma)',
#        'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer',
#        'lung cancer', 'lung cancer', 'hamartoma', 'unknown',
#        'lung abscess', 'lung cancer(bronchioloalveolar cell carcinoma)',
#        'lung cancer', 'lung cancer', 'Cryptococcosis', 'lung cancer',
#        'lung cancer', 'lung cancer(bronchioloalveolar cell carcinoma)',
#        'tuberculoma', 'lung cancer(adenocarcinoma)', 'tuberculoma',
#        'lung cancer', 'lung cancer(adenocarcinoma)', 'lung cancer',
#        'lung cancer(adenocarcinoma)', 'lung cancer', 'lung cancer',
#        'tuberculoma', 'lung cancer', 'lung cancer(adenocarcinoma)',
# ...

# %%
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.title("DISEASES")
plt.pyplot.xlabel("NO_OF_DISEASES")
plt.pyplot.ylabel("PATIENTS")
plt.pyplot.hist(d['diagnosis'])
# Out:
# (array([167.,  33.,  13.,   5.,   8.,   7.,   3.,   3.,   4.,   4.]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <BarContainer object of 10 artists>)
